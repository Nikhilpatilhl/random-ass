# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import KFold
from sklearn.ensemble import RandomForestClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn import tree
from sklearn.metrics import classification_report
from sklearn import preprocessing
from sklearn.model_selection import GridSearchCV
from sklearn import metrics
import warnings
warnings.filterwarnings("ignore")

# %%
ac = pd.read_csv("Company_Data.csv")
ac
# Out:
#      Sales  CompPrice  Income  Advertising  Population  Price ShelveLoc  Age  \
# 0     9.50        138      73           11         276    120       Bad   42
# 1    11.22        111      48           16         260     83      Good   65
# 2    10.06        113      35           10         269     80    Medium   59
# 3     7.40        117     100            4         466     97    Medium   55
# 4     4.15        141      64            3         340    128       Bad   38
# ..     ...        ...     ...          ...         ...    ...       ...  ...
# 395  12.57        138     108           17         203    128      Good   33
# 396   6.14        139      23            3          37    120    Medium   55
# 397   7.41        162      26           12         368    159    Medium   40
# 398   5.94        100      79            7         284     95       Bad   50
# 399   9.71        134      37            0          27    120      Good   49
#
#      Education Urban   US
# 0           17   Yes  Yes
# 1           10   Yes  Yes
# 2           12   Yes  Yes
# 3           14   Yes  Yes
# 4           13   Yes   No
# ..         ...   ...  ...
# 395         14   Yes  Yes
# 396         11    No  Yes
# 397         18   Yes  Yes
# 398         12   Yes  Yes
# 399         16   Yes  Yes
#
# [400 rows x 11 columns]

# %%
ac.isna().sum()
# Out:
# Sales          0
# CompPrice      0
# Income         0
# Advertising    0
# Population     0
# Price          0
# ShelveLoc      0
# Age            0
# Education      0
# Urban          0
# US             0
# dtype: int64

# %%
ac
# Out:
#      Sales  CompPrice  Income  Advertising  Population  Price ShelveLoc  Age  \
# 0     9.50        138      73           11         276    120       Bad   42
# 1    11.22        111      48           16         260     83      Good   65
# 2    10.06        113      35           10         269     80    Medium   59
# 3     7.40        117     100            4         466     97    Medium   55
# 4     4.15        141      64            3         340    128       Bad   38
# ..     ...        ...     ...          ...         ...    ...       ...  ...
# 395  12.57        138     108           17         203    128      Good   33
# 396   6.14        139      23            3          37    120    Medium   55
# 397   7.41        162      26           12         368    159    Medium   40
# 398   5.94        100      79            7         284     95       Bad   50
# 399   9.71        134      37            0          27    120      Good   49
#
#      Education Urban   US
# 0           17   Yes  Yes
# 1           10   Yes  Yes
# 2           12   Yes  Yes
# 3           14   Yes  Yes
# 4           13   Yes   No
# ..         ...   ...  ...
# 395         14   Yes  Yes
# 396         11    No  Yes
# 397         18   Yes  Yes
# 398         12   Yes  Yes
# 399         16   Yes  Yes
#
# [400 rows x 11 columns]

# %%
ac.shape
# Out:
# (400, 11)

# %%
ac.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 400 entries, 0 to 399
# Data columns (total 11 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Sales        400 non-null    float64
#  1   CompPrice    400 non-null    int64
#  2   Income       400 non-null    int64
#  3   Advertising  400 non-null    int64
#  4   Population   400 non-null    int64
#  5   Price        400 non-null    int64
#  6   ShelveLoc    400 non-null    object
#  7   Age          400 non-null    int64
#  8   Education    400 non-null    int64
#  9   Urban        400 non-null    object
#  10  US           400 non-null    object
# dtypes: float64(1), int64(7), object(3)
# memory usage: 34.5+ KB

# %%
ac['ShelveLoc'].unique(),ac['Urban'].unique(),ac['US'].unique()
# Out:
# (array(['Bad', 'Good', 'Medium'], dtype=object),
#  array(['Yes', 'No'], dtype=object),
#  array(['Yes', 'No'], dtype=object))

# %%
from sklearn.preprocessing import LabelEncoder
LE=LabelEncoder()

# %%
ac['ShelveLoc']=LE.fit_transform(ac['ShelveLoc'])
ac['Urban']=LE.fit_transform(ac['Urban'])
ac['US']=LE.fit_transform(ac['US'])

# %%
ac.dtypes
# Out:
# Sales          float64
# CompPrice        int64
# Income           int64
# Advertising      int64
# Population       int64
# Price            int64
# ShelveLoc        int32
# Age              int64
# Education        int64
# Urban            int32
# US               int32
# dtype: object

# %%
ac
# Out:
#      Sales  CompPrice  Income  Advertising  Population  Price  ShelveLoc  Age  \
# 0     9.50        138      73           11         276    120          0   42
# 1    11.22        111      48           16         260     83          1   65
# 2    10.06        113      35           10         269     80          2   59
# 3     7.40        117     100            4         466     97          2   55
# 4     4.15        141      64            3         340    128          0   38
# ..     ...        ...     ...          ...         ...    ...        ...  ...
# 395  12.57        138     108           17         203    128          1   33
# 396   6.14        139      23            3          37    120          2   55
# 397   7.41        162      26           12         368    159          2   40
# 398   5.94        100      79            7         284     95          0   50
# 399   9.71        134      37            0          27    120          1   49
#
#      Education  Urban  US
# 0           17      1   1
# 1           10      1   1
# 2           12      1   1
# 3           14      1   1
# 4           13      1   0
# ..         ...    ...  ..
# 395         14      1   1
# 396         11      0   1
# 397         18      1   1
# 398         12      1   1
# 399         16      1   1
#
# [400 rows x 11 columns]

# %% [markdown]
# # CONVERTING SALES

# %%
ac.insert(11,"SalesVariable",'')
ac
# Out:
#      Sales  CompPrice  Income  Advertising  Population  Price  ShelveLoc  Age  \
# 0     9.50        138      73           11         276    120          0   42
# 1    11.22        111      48           16         260     83          1   65
# 2    10.06        113      35           10         269     80          2   59
# 3     7.40        117     100            4         466     97          2   55
# 4     4.15        141      64            3         340    128          0   38
# ..     ...        ...     ...          ...         ...    ...        ...  ...
# 395  12.57        138     108           17         203    128          1   33
# 396   6.14        139      23            3          37    120          2   55
# 397   7.41        162      26           12         368    159          2   40
# 398   5.94        100      79            7         284     95          0   50
# 399   9.71        134      37            0          27    120          1   49
#
#      Education  Urban  US SalesVariable
# 0           17      1   1
# 1           10      1   1
# 2           12      1   1
# 3           14      1   1
# 4           13      1   0
# ..         ...    ...  ..           ...
# 395         14      1   1
# 396         11      0   1
# 397         18      1   1
# 398         12      1   1
# 399         16      1   1
#
# [400 rows x 12 columns]

# %%
for i in range(0,len(ac['Sales'])):
    if ac['Sales'][i]>=11.0:
        ac['SalesVariable'][i] ='High'
    elif ac['Sales'][i]<=6.0:
        ac['SalesVariable'][i] = 'Low'
    else:
        ac['SalesVariable'][i] = 'Medium'

# %%
ac
# Out:
#      Sales  CompPrice  Income  Advertising  Population  Price  ShelveLoc  Age  \
# 0     9.50        138      73           11         276    120          0   42
# 1    11.22        111      48           16         260     83          1   65
# 2    10.06        113      35           10         269     80          2   59
# 3     7.40        117     100            4         466     97          2   55
# 4     4.15        141      64            3         340    128          0   38
# ..     ...        ...     ...          ...         ...    ...        ...  ...
# 395  12.57        138     108           17         203    128          1   33
# 396   6.14        139      23            3          37    120          2   55
# 397   7.41        162      26           12         368    159          2   40
# 398   5.94        100      79            7         284     95          0   50
# 399   9.71        134      37            0          27    120          1   49
#
#      Education  Urban  US SalesVariable
# 0           17      1   1        Medium
# 1           10      1   1          High
# 2           12      1   1        Medium
# 3           14      1   1        Medium
# 4           13      1   0           Low
# ..         ...    ...  ..           ...
# 395         14      1   1          High
# 396         11      0   1        Medium
# 397         18      1   1        Medium
# 398         12      1   1           Low
# 399         16      1   1        Medium
#
# [400 rows x 12 columns]

# %%
plt.figure(figsize=(10,10))
plt.scatter(cd['Income'],cd['Sales'],color='darkviolet')
plt.ylabel("Income",size=19)
plt.xlabel("Sales",size=19)
plt.show()

# %% [markdown]
# # model bulding

# %%
X=cd.iloc[:,1:-1]
Y=cd.iloc[:,-1]

# %%
x.head()
# Out:
#    CompPrice  Income  Advertising  Population  Price  ShelveLoc  Age  \
# 0        138      73           11         276    120          0   42
# 1        111      48           16         260     83          1   65
# 2        113      35           10         269     80          2   59
# 3        117     100            4         466     97          2   55
# 4        141      64            3         340    128          0   38
#
#    Education  Urban  US
# 0         17      1   1
# 1         10      1   1
# 2         12      1   1
# 3         14      1   1
# 4         13      1   0

# %%
Y.head()
# Out:
# 0    Medium
# 1      High
# 2    Medium
# 3    Medium
# 4       Low
# Name: SalesVariable, dtype: object

# %% [markdown]
# # SPLIT INTO TRAIANING AND TESTING DATA

# %%
x_train,x_test,y_train,y_test=train_test_split(X,Y,test_size=.25,random_state=7)
x_train.shape,x_test.shape,y_train.shape,y_test.shape
# Out:
# ((300, 10), (100, 10), (300,), (100,))

# %%
y_train
# Out:
# 382       Low
# 84        Low
# 115    Medium
# 328       Low
# 99        Low
#         ...
# 211    Medium
# 67     Medium
# 25       High
# 196       Low
# 175    Medium
# Name: SalesVariable, Length: 300, dtype: object

# %%
y_test
# Out:
# 265       Low
# 65        Low
# 120    Medium
# 132    Medium
# 378    Medium
#         ...
# 288    Medium
# 66     Medium
# 303    Medium
# 165       Low
# 101    Medium
# Name: SalesVariable, Length: 100, dtype: object

# %%
x_train
# Out:
#      CompPrice  Income  Advertising  Population  Price  ShelveLoc  Age  \
# 382        121      28           19         315    121          2   66
# 84         111      25            0          52    121          0   43
# 115        139      35            0          95    129          2   42
# 328        117      66            1          65    111          0   55
# 99         121      47            3         220    107          0   56
# ..         ...     ...          ...         ...    ...        ...  ...
# 211        117     118           14         445    120          2   32
# 67         126      61           14         152    115          2   47
# 25         139      32            0         176     82          1   54
# 196        130      28            6         410    133          0   72
# 175        115      89            0          38    122          2   25
#
#      Education  Urban  US
# 382         14      1   1
# 84          18      0   0
# 115         13      1   0
# 328         11      1   1
# 99          16      0   1
# ..         ...    ...  ..
# 211         15      1   1
# 67          16      1   1
# 25          11      0   0
# 196         16      1   1
# 175         12      1   0
#
# [300 rows x 10 columns]

# %%
x_test
# Out:
#      CompPrice  Income  Advertising  Population  Price  ShelveLoc  Age  \
# 265        130      35           10         402    129          0   39
# 65         122      26            0         197    128          2   55
# 120        128     105           11         249    131          2   63
# 132        125      87            9         232    136          1   72
# 378        133      88            3         105    119          2   79
# ..         ...     ...          ...         ...    ...        ...  ...
# 288        116      40            0          74     97          2   76
# 66         127      92            0         508     91          2   56
# 303        133      52           16         290     99          2   43
# 165        147      58            7         100    191          0   27
# 101        128      93            0          89    118          2   34
#
#      Education  Urban  US
# 265         17      1   1
# 65          13      0   0
# 120         13      1   1
# 132         10      1   1
# 378         12      1   1
# ..         ...    ...  ..
# 288         15      0   0
# 66          18      1   0
# 303         11      1   1
# 165         15      1   1
# 101         18      1   0
#
# [100 rows x 10 columns]

# %%
import matplotlib.pyplot as plt 
# %matplotlib inline
# choose k between 1 to 41
num_trees = [10,20,50,100,200,300,400,500,600,700,800,1000]
nf=[2,3,4,5,6]
k_scores = []




for k in num_trees:

    rf = RandomForestClassifier(n_estimators=k)
    scores = cross_val_score(rf, x_train, y_train, cv=10)
    k_scores.append(scores.mean())

plt.figure(figsize=(30,10))
plt.bar(num_trees, k_scores)
plt.plot(num_trees, k_scores,color="red")

plt.xlabel('Number of tress')
plt.ylabel('Cross-Validated Accuracy')
plt.show()

# %% [markdown]
# # GRID SEARCH CV TO FIND BEST HYPERPARAMETER

# %%
from sklearn.model_selection import GridSearchCV

mod=RandomForestClassifier()
parameters={
    
    "n_estimators":[130, 140, 150, 160],
    "max_features":[4,5,6,7]
}

Grid_DT=GridSearchCV(mod,parameters,cv=10)

Grid_DT.fit(x_train,y_train)

Grid_DT.best_params_
# Out:
# {'max_features': 7, 'n_estimators': 160}

# %%
model2=RandomForestClassifier(max_features=6, n_estimators= 150)

# %%
model2.fit(x_train,y_train)
# Out:
# RandomForestClassifier(max_features=6, n_estimators=150)

# %%
print(classification_report(y_test,model2.predict(x_test)))
# Out:
#               precision    recall  f1-score   support
#
#         High       1.00      0.40      0.57        10
#          Low       0.76      0.73      0.75        30
#       Medium       0.79      0.88      0.83        60
#
#     accuracy                           0.79       100
#    macro avg       0.85      0.67      0.72       100
# weighted avg       0.80      0.79      0.78       100

# %%
model2.feature_importances_
# Out:
# array([0.13336663, 0.10473678, 0.10300842, 0.09948561, 0.2152947 ,
#        0.13503027, 0.11617863, 0.07208968, 0.0099653 , 0.01084398])

# %% [markdown]
# # GINI INDEX WITH TREE ESTIMATORS

# %%
model=DecisionTreeClassifier(criterion='gini',min_samples_split=6)
model.fit(x_train,y_train)
# Out:
# DecisionTreeClassifier(min_samples_split=6)

# %%
pred=Grid_DT.predict(x_test)
pd.Series(pred).value_counts()
# Out:
# Medium    66
# Low       29
# High       5
# dtype: int64

# %% [raw]
# metrics.accuracy_score(pred,y_test)

# %%
print(classification_report(y_test,pred))
# Out:
#               precision    recall  f1-score   support
#
#         High       0.60      0.30      0.40        10
#          Low       0.72      0.70      0.71        30
#       Medium       0.76      0.83      0.79        60
#
#     accuracy                           0.74       100
#    macro avg       0.69      0.61      0.64       100
# weighted avg       0.73      0.74      0.73       100

# %%
from sklearn.metrics import confusion_matrix
print(confusion_matrix(y_test,pred))
# Out:
# [[ 3  0  7]
#  [ 0 21  9]
#  [ 2  8 50]]

# %%
fe=['CompPrice','Income','Advertising','Population','Prize','ShelveLoc',
    'Age','Education','Urban','US']
ta=['Low','Medium','High']
fig,axes=plt.subplots(figsize=(5,5),dpi=1000)
tree.plot_tree(model,feature_names=fe,class_names=ta,filled= True);
plt.show()
